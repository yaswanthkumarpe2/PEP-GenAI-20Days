# %%
text = """
AI is transforming education.
RAG helps reduce hallucination.
Embeddings convert text into vectors.
"""

print(text)
# Out:
# AI is transforming education.
# RAG helps reduce hallucination.
# Embeddings convert text into vectors.

# %%
chunks = text.split(".")

print(chunks)
# Out:
# ['\nAI is transforming education', '\nRAG helps reduce hallucination', '\nEmbeddings convert text into vectors', '\n']

# %%
chunks = [chunk.strip() for chunk in chunks if chunk.strip()]

print(chunks)
# Out:
# ['AI is transforming education', 'RAG helps reduce hallucination', 'Embeddings convert text into vectors']

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (5.2.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (5.2.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: numpy in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: shellingham in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: anyio in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: typer>=0.24.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\yaswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\yaswa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

sentence = "AI is transforming education"

embedding = model.encode(sentence)

print(embedding.shape)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 807.86it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# (384,)

# %%
embeddings = model.encode(chunks)

print(embeddings.shape)
# Out:
# (3, 384)

# %%
query = "What reduces hallucination?"

print(query)
# Out:
# What reduces hallucination?

# %%
query_embedding = model.encode(query)

print(query_embedding.shape)
print(query_embedding)
# Out:
# (384,)
# [ 5.11660837e-02  9.15844366e-02  5.64882951e-03  3.68910730e-02
#   3.73454727e-02  2.76620481e-02 -7.76967965e-03  9.77893453e-03
#  -9.60126612e-03  8.31867196e-03 -2.95385215e-02 -1.09153455e-02
#  -2.13119742e-02  1.68188959e-02  3.14484164e-02  7.06709251e-02
#  -2.68221125e-02  1.31524712e-01 -1.03542097e-02 -6.43752292e-02
#   4.21554670e-02 -2.45800056e-02  3.48273595e-03  1.25734061e-02
#   2.72315666e-02 -1.10445125e-03 -1.03656454e-02 -5.76008707e-02
#  -3.03957332e-02 -1.01453327e-01  7.79504515e-03  8.79572257e-02
#  -5.77508025e-02 -3.38090472e-02 -2.77526323e-02  5.70426993e-02
#  -5.37859350e-02  4.77139913e-02  2.40963679e-02 -1.20401485e-02
#  -1.10618155e-02  1.80279408e-02 -3.87778617e-02  4.72804438e-03
#  -6.48529036e-04  4.66874465e-02  5.16645052e-03  4.10176814e-03
#  -3.97382304e-02 -4.68871221e-02 -3.99706280e-03  1.12993121e-02
#  -3.34590040e-02  3.65911275e-02 -2.08562277e-02  2.48613246e-02
#  -2.66265795e-02  5.28573431e-02  1.89750604e-02  3.40037905e-02
#  -5.43800741e-02  6.59416104e-03 -6.74859434e-02 -2.46026311e-02
#   4.69638892e-02  4.00560349e-02  8.87412578e-04  5.17140655e-03
#   5.28892986e-02  5.67347929e-02  8.26661885e-02 -1.96802374e-02
#  -1.53337074e-02  2.24110354e-02  8.71530101e-02 -4.66390774e-02
#  -5.68776950e-02 -1.26378939e-01  2.49697492e-02  2.12322939e-02
#  -2.15871539e-02  6.35025427e-02 -1.86330918e-02  3.37572768e-02
#   4.15960774e-02 -1.20362230e-02  3.86284031e-02 -1.30077852e-02
#  -1.14347786e-01  3.48254703e-02 -1.12539334e-02 -1.02430478e-01
#  -9.54175368e-02 -2.55972482e-02 -4.86226156e-02  2.55558565e-02
#  -5.61354309e-02 -5.41804433e-02 -7.24184960e-02  3.96001479e-03
#   4.18509655e-02  1.63309146e-02 -4.87657674e-02  3.62812392e-02
#  -1.42959487e-02  6.04741350e-02  3.19086127e-02 -2.44099647e-02
#  -4.44895960e-02 -3.83487381e-02 -2.21251976e-03 -4.47754376e-02
#  -1.95036624e-02 -7.96354469e-03  5.29079810e-02  5.39598651e-02
#  -3.33567932e-02  2.70706192e-02 -1.12939002e-02 -2.30394807e-02
#  -5.61731029e-03  4.13727202e-02 -3.24553400e-02  1.43788561e-01
#   8.43666717e-02  7.86260143e-02  7.73512572e-02  4.04172502e-02
#   3.38004455e-02  3.28268856e-02 -4.48949598e-02 -5.21346778e-02
#  -2.14233808e-02  2.28022337e-02  5.24377823e-03 -8.67252424e-02
#  -7.21245483e-02 -3.64882275e-02 -6.00913838e-02 -3.42989974e-02
#   1.50031680e-02 -5.99040501e-02 -1.92727465e-02  4.13386188e-02
#  -4.31805328e-02  2.93026548e-02 -2.27161478e-02 -7.97101930e-02
#  -1.83572993e-02  3.87136266e-02  3.48794321e-03 -1.32751197e-08
#  -1.73771996e-02 -6.83770105e-02 -5.01673948e-03 -2.41886955e-02
#   1.87884364e-02 -5.27206659e-02  5.84847331e-02  1.19968064e-01
#   4.80356812e-03 -1.23332873e-01  2.95277629e-02  5.92567772e-02
#   1.15006641e-01  7.86408409e-03  5.77881895e-02  1.06260525e-02
#   8.21216777e-02  7.79764727e-02 -1.21974880e-02 -7.08718151e-02
#  -2.62858272e-02 -6.23482279e-02 -2.80336197e-02 -1.12361070e-02
#  -1.28219305e-02  1.83246396e-02  1.32556245e-01  1.93264708e-02
#  -1.34573700e-02 -7.50965923e-02  1.14078335e-01  3.19491923e-02
#   4.80248593e-02  7.24122766e-03 -6.95925811e-03  3.51898894e-02
#   3.13831829e-02  2.23082956e-02  5.30043244e-02  2.63126064e-02
#  -3.53462510e-02 -2.71090157e-02  1.54669862e-02  6.10906743e-02
#  -1.12543525e-02 -7.60307983e-02  9.15805027e-02 -5.17811161e-03
#  -2.05777045e-02  3.91449332e-02 -2.18498614e-03  9.47650671e-02
#   2.55673118e-02 -2.11621635e-02 -2.76609249e-02  8.29870924e-02
#   7.40482509e-02 -1.28182601e-02  3.41645000e-03 -5.91040626e-02
#   5.61052486e-02 -4.29903530e-02 -2.37829089e-02  5.82923926e-02]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarities = cosine_similarity(
    [query_embedding],
    embeddings
)

print(similarities)
# Out:
# [[ 0.05234286  0.7177212  -0.07611952]]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarities = cosine_similarity(
    [query_embedding],
    embeddings
)

print(similarities)
# Out:
# [[ 0.05234286  0.7177212  -0.07611952]]

# %%
best_match_index = similarities.argmax()

print(chunks[best_match_index])
# Out:
# RAG helps reduce hallucination

# %%
context = chunks[best_match_index]

prompt = f"""
Answer the question using the context below.

Context:
{context}

Question:
{query}

Answer:
"""

print(prompt)
# Out:
# Answer the question using the context below.
#
# Context:
# RAG helps reduce hallucination
#
# Question:
# What reduces hallucination?
#
# Answer:

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response = model.generate_content(prompt)
#       2
#       3 print(response.text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'SentenceTransformer' object has no attribute 'generate_content'
